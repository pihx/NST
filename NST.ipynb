# %% [markdown]
# <a href="https://colab.research.google.com/github/pihx/NST/blob/main/NST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Style Transfer training

# %% [markdown]
# Download NST code from github

# %%
# !git clone https://github.com/pihx/NST.git

# %%
cd NST

# %%
ls

# %% [markdown]
# Start training of NST picture. Check Runtime is default CPU(None)

# %%
# !python style_transfer3.py

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Change Runtime type to GPU, then run NST training of NST again. (!python style_transfer3.py)

# %%
# !python style_transfer3.py

# %% [markdown]
# Change Runtime type to TPU, then run NST training of NST again.

# %%
# !python style_transfer3.py

# %%
filename = "./data.txt"
target = open(filename,'r+')
var1,var2,var3 = target.readlines()


print(f"Here is the data: {var1}{var2}{var3}")



names = ['CPU(None)', 'GPU', 'TPU']
values = [var1, var2, var3]


plt.bar(names, values)
plt.title('Training duration by Runtime Types')
plt.xlabel('Runtime Type')
plt.ylabel('Training (minutes)')
plt.show()
