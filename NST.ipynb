# %% [markdown]
# <a href="https://colab.research.google.com/github/pihx/NST/blob/main/NST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Style Transfer training

# %% [markdown]
# Download NST code from github

# %%
# !git clone https://github.com/pihx/NST.git
# Out:
# Cloning into 'NST'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
cd NST
# Out:
# /content/NST

# %%
ls
# Out:
# content/   README.md         styles/             style_transfer2.py
# prerun.sh  requirements.txt  style_transfer1.py  style_transfer3.py

# %% [markdown]
# Start training of NST picture

# %%
# !python style_transfer3.py
# Out:
# ...
# 58889256/58889256 [==============================] - 1s 0us/step
# 2022-10-25 17:22:29.102847: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:Functional model inputs must come from `tf.keras.Input` (thus holding past layer metadata). They cannot be the output of a previous non-Input layer. Here, a tensor specified as input to "model" was not an Input tensor, it was generated by layer "input_1".
# Note that input tensors are instantiated via `tensor = tf.keras.Input(shape)`.
# The tensor that caused the issue was: Tensor("input_1:0", shape=(None, 397, 635, 3), dtype=float32)
# WARNING:tensorflow:Functional model inputs must come from `tf.keras.Input` (thus holding past layer metadata). They cannot be the output of a previous non-Input layer. Here, a tensor specified as input to "model" was not an Input tensor, it was generated by layer "input_1".
# ...

# %% [markdown]
# Training was done with GPU, to change compute to TPU do the following:
#  Click downarrow by RAM Disk, then "Change runtime type", Change GPU to TPU (or None)
#
# ![colabSelectRuntimeType.png](data:image/png;base64,...)
